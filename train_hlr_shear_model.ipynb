# %% [markdown]
# # Training HLR shear model

# %%
import shear_util as su
import pandas as pd
import numpy as np
import scipy
import galsim

gsp = galsim.GSParams(maximum_fft_size=150000)
np.random.seed(2019)

ngal = 200
e_list = np.linspace(0.0,0.97,ngal)

galsim_scale=0.01
# the smaller the scale the more accurate estimated hlrs by galsim
# but it'll also lead to more nan results for high e's

hlr_preshear = 1.0 # for the round version before shearing
data = {'e':e_list}

for magnify in [True, False]:
    
    hlr_quad_list = []
    hlr_wh_list = []
    hlr_galsim_list = []
    
    for e in e_list:
        phi = np.pi*np.random.random(1)[0] # we only need one
        e1 = e*np.cos(2*phi)
        e2 = e*np.sin(2*phi)
        mu = 1./(1-e**2)
        sigma_round = hlr_preshear/np.sqrt(2.*np.log(2))

        if magnify: # equivalent of galsim.lens() = galsim.shear() + galsim.magnify()
            # https://galsim-developers.github.io/GalSim/_build/html/gsobject.html#galsim.GSObject.lens
            sigma_x = sigma_round/(1-e)
            sigma_y = sigma_round/(1+e)
        else: # equivalent of galsim.shear() -- area or "total" flux preseved
            # https://galsim-developers.github.io/GalSim/_build/html/gsobject.html#galsim.GSObject.shear
            sigma_x = sigma_round * np.sqrt((1+e)/(1-e))
            sigma_y = sigma_round * np.sqrt((1-e)/(1+e))

        # method 1: integrating analytic equation using quad methos
        hlr_quad = su.get_hlr_postshear(hlr_preshear, e, magnify=magnify)

        # method 2: good approximation using the Wilson-Hilferty transformation - eq. 18 of https://apps.dtic.mil/dtic/tr/fulltext/u2/1043284.pdf
        hlr_wh = np.sqrt( (sigma_x**2+sigma_y**2)*(1-2*(sigma_x**4+sigma_y**4)/9/(sigma_x**2+sigma_y**2)**2)**3 )

        # method 3: galsim image analysis
        gal = galsim.Gaussian(half_light_radius=hlr_preshear, gsparams=gsp)
        gal = gal.shear(g1=e1, g2=e2)

        if magnify:
            gal = gal.magnify(mu)

        hlr_galsim = gal.calculateHLR(scale=galsim_scale)

        # print some stat
        print(f'[e={e:.3f}, magnify={magnify}] analytic/quad light_frac(r={hlr_quad:.3f}): {su.prob_bivariate_gaussian(0, hlr_quad, sigma_x, sigma_y):.4f},'+
                       f' galsim light_frac(r={hlr_galsim:.3f}): {su.prob_bivariate_gaussian(0, hlr_galsim, sigma_x, sigma_y):.4f}')

        # append
        hlr_quad_list.append(hlr_quad)
        hlr_wh_list.append(hlr_wh)
        hlr_galsim_list.append(hlr_galsim)

    postfix = '_magnified' if magnify else ''
    data['scale_analytic'+postfix] = hlr_quad_list
    data['scale_galsim'+postfix] = hlr_galsim_list
    data['scale_wh'+postfix] = hlr_wh_list
# Out:
# [e=0.000, magnify=True] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.005, magnify=True] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.010, magnify=True] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.015, magnify=True] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.019, magnify=True] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.024, magnify=True] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.029, magnify=True] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.034, magnify=True] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.039, magnify=True] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.044, magnify=True] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.049, magnify=True] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.054, magnify=True] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.058, magnify=True] analytic/quad light_frac(r=1.003): 0.5000, galsim light_frac(r=1.003): 0.5001
# [e=0.063, magnify=True] analytic/quad light_frac(r=1.003): 0.5000, galsim light_frac(r=1.003): 0.5000
# [e=0.068, magnify=True] analytic/quad light_frac(r=1.004): 0.5000, galsim light_frac(r=1.004): 0.4999
# [e=0.073, magnify=True] analytic/quad light_frac(r=1.005): 0.5000, galsim light_frac(r=1.005): 0.5000
# [e=0.078, magnify=True] analytic/quad light_frac(r=1.005): 0.5000, galsim light_frac(r=1.005): 0.5000
# [e=0.083, magnify=True] analytic/quad light_frac(r=1.006): 0.5000, galsim light_frac(r=1.006): 0.5000
# [e=0.088, magnify=True] analytic/quad light_frac(r=1.007): 0.5000, galsim light_frac(r=1.007): 0.5001
# [e=0.093, magnify=True] analytic/quad light_frac(r=1.007): 0.5000, galsim light_frac(r=1.007): 0.5000
# [e=0.097, magnify=True] analytic/quad light_frac(r=1.008): 0.5000, galsim light_frac(r=1.008): 0.5001
# [e=0.102, magnify=True] analytic/quad light_frac(r=1.009): 0.5000, galsim light_frac(r=1.009): 0.5000
# [e=0.107, magnify=True] analytic/quad light_frac(r=1.010): 0.5000, galsim light_frac(r=1.010): 0.5000
# [e=0.112, magnify=True] analytic/quad light_frac(r=1.011): 0.5000, galsim light_frac(r=1.011): 0.5000
# [e=0.117, magnify=True] analytic/quad light_frac(r=1.012): 0.5000, galsim light_frac(r=1.012): 0.5001
# [e=0.122, magnify=True] analytic/quad light_frac(r=1.013): 0.5000, galsim light_frac(r=1.013): 0.5000
# [e=0.127, magnify=True] analytic/quad light_frac(r=1.014): 0.5000, galsim light_frac(r=1.014): 0.5000
# [e=0.132, magnify=True] analytic/quad light_frac(r=1.015): 0.5000, galsim light_frac(r=1.015): 0.5000
# [e=0.136, magnify=True] analytic/quad light_frac(r=1.016): 0.5000, galsim light_frac(r=1.016): 0.4999
# [e=0.141, magnify=True] analytic/quad light_frac(r=1.017): 0.5000, galsim light_frac(r=1.017): 0.5000
# [e=0.146, magnify=True] analytic/quad light_frac(r=1.019): 0.5000, galsim light_frac(r=1.019): 0.5000
# [e=0.151, magnify=True] analytic/quad light_frac(r=1.020): 0.5000, galsim light_frac(r=1.020): 0.4999
# [e=0.156, magnify=True] analytic/quad light_frac(r=1.021): 0.5000, galsim light_frac(r=1.021): 0.5000
# [e=0.161, magnify=True] analytic/quad light_frac(r=1.023): 0.5000, galsim light_frac(r=1.023): 0.5000
# [e=0.166, magnify=True] analytic/quad light_frac(r=1.024): 0.5000, galsim light_frac(r=1.024): 0.4999
# [e=0.171, magnify=True] analytic/quad light_frac(r=1.026): 0.5000, galsim light_frac(r=1.026): 0.5000
# [e=0.175, magnify=True] analytic/quad light_frac(r=1.027): 0.5000, galsim light_frac(r=1.027): 0.5000
# [e=0.180, magnify=True] analytic/quad light_frac(r=1.029): 0.5000, galsim light_frac(r=1.029): 0.5000
# [e=0.185, magnify=True] analytic/quad light_frac(r=1.030): 0.5000, galsim light_frac(r=1.030): 0.5000
# [e=0.190, magnify=True] analytic/quad light_frac(r=1.032): 0.5000, galsim light_frac(r=1.032): 0.5000
# [e=0.195, magnify=True] analytic/quad light_frac(r=1.034): 0.5000, galsim light_frac(r=1.034): 0.5000
# [e=0.200, magnify=True] analytic/quad light_frac(r=1.036): 0.5000, galsim light_frac(r=1.036): 0.5001
# [e=0.205, magnify=True] analytic/quad light_frac(r=1.037): 0.5000, galsim light_frac(r=1.037): 0.5000
# [e=0.210, magnify=True] analytic/quad light_frac(r=1.039): 0.5000, galsim light_frac(r=1.039): 0.5000
# [e=0.214, magnify=True] analytic/quad light_frac(r=1.041): 0.5000, galsim light_frac(r=1.041): 0.5000
# [e=0.219, magnify=True] analytic/quad light_frac(r=1.043): 0.5000, galsim light_frac(r=1.043): 0.5000
# [e=0.224, magnify=True] analytic/quad light_frac(r=1.045): 0.5000, galsim light_frac(r=1.045): 0.5000
# [e=0.229, magnify=True] analytic/quad light_frac(r=1.047): 0.5000, galsim light_frac(r=1.048): 0.5000
# [e=0.234, magnify=True] analytic/quad light_frac(r=1.050): 0.5000, galsim light_frac(r=1.050): 0.5000
# [e=0.239, magnify=True] analytic/quad light_frac(r=1.052): 0.5000, galsim light_frac(r=1.052): 0.5000
# [e=0.244, magnify=True] analytic/quad light_frac(r=1.054): 0.5000, galsim light_frac(r=1.054): 0.5000
# [e=0.249, magnify=True] analytic/quad light_frac(r=1.057): 0.5000, galsim light_frac(r=1.057): 0.5001
# [e=0.253, magnify=True] analytic/quad light_frac(r=1.059): 0.5000, galsim light_frac(r=1.059): 0.4999
# [e=0.258, magnify=True] analytic/quad light_frac(r=1.062): 0.5000, galsim light_frac(r=1.062): 0.5001
# [e=0.263, magnify=True] analytic/quad light_frac(r=1.064): 0.5000, galsim light_frac(r=1.064): 0.5000
# [e=0.268, magnify=True] analytic/quad light_frac(r=1.067): 0.5000, galsim light_frac(r=1.067): 0.5001
# [e=0.273, magnify=True] analytic/quad light_frac(r=1.069): 0.5000, galsim light_frac(r=1.069): 0.5000
# [e=0.278, magnify=True] analytic/quad light_frac(r=1.072): 0.5000, galsim light_frac(r=1.072): 0.5000
# [e=0.283, magnify=True] analytic/quad light_frac(r=1.075): 0.5000, galsim light_frac(r=1.075): 0.4999
# [e=0.288, magnify=True] analytic/quad light_frac(r=1.078): 0.5000, galsim light_frac(r=1.078): 0.5000
# [e=0.292, magnify=True] analytic/quad light_frac(r=1.081): 0.5000, galsim light_frac(r=1.081): 0.5000
# [e=0.297, magnify=True] analytic/quad light_frac(r=1.084): 0.5000, galsim light_frac(r=1.084): 0.5000
# [e=0.302, magnify=True] analytic/quad light_frac(r=1.087): 0.5000, galsim light_frac(r=1.087): 0.5000
# [e=0.307, magnify=True] analytic/quad light_frac(r=1.090): 0.5000, galsim light_frac(r=1.090): 0.5000
# [e=0.312, magnify=True] analytic/quad light_frac(r=1.094): 0.5000, galsim light_frac(r=1.093): 0.5000
# [e=0.317, magnify=True] analytic/quad light_frac(r=1.097): 0.5000, galsim light_frac(r=1.097): 0.5001
# [e=0.322, magnify=True] analytic/quad light_frac(r=1.100): 0.5000, galsim light_frac(r=1.100): 0.5000
# [e=0.327, magnify=True] analytic/quad light_frac(r=1.104): 0.5000, galsim light_frac(r=1.104): 0.4999
# [e=0.331, magnify=True] analytic/quad light_frac(r=1.107): 0.5000, galsim light_frac(r=1.107): 0.5000
# [e=0.336, magnify=True] analytic/quad light_frac(r=1.111): 0.5000, galsim light_frac(r=1.111): 0.5000
# [e=0.341, magnify=True] analytic/quad light_frac(r=1.115): 0.5000, galsim light_frac(r=1.115): 0.4999
# [e=0.346, magnify=True] analytic/quad light_frac(r=1.119): 0.5000, galsim light_frac(r=1.119): 0.5000
# [e=0.351, magnify=True] analytic/quad light_frac(r=1.123): 0.5000, galsim light_frac(r=1.123): 0.5000
# [e=0.356, magnify=True] analytic/quad light_frac(r=1.127): 0.5000, galsim light_frac(r=1.127): 0.5000
# [e=0.361, magnify=True] analytic/quad light_frac(r=1.131): 0.5000, galsim light_frac(r=1.131): 0.5000
# [e=0.366, magnify=True] analytic/quad light_frac(r=1.135): 0.5000, galsim light_frac(r=1.135): 0.5000
# [e=0.370, magnify=True] analytic/quad light_frac(r=1.140): 0.5000, galsim light_frac(r=1.139): 0.4999
# [e=0.375, magnify=True] analytic/quad light_frac(r=1.144): 0.5000, galsim light_frac(r=1.144): 0.4999
# [e=0.380, magnify=True] analytic/quad light_frac(r=1.149): 0.5000, galsim light_frac(r=1.149): 0.5000
# [e=0.385, magnify=True] analytic/quad light_frac(r=1.153): 0.5000, galsim light_frac(r=1.153): 0.5000
# [e=0.390, magnify=True] analytic/quad light_frac(r=1.158): 0.5000, galsim light_frac(r=1.158): 0.4999
# [e=0.395, magnify=True] analytic/quad light_frac(r=1.163): 0.5000, galsim light_frac(r=1.163): 0.5000
# [e=0.400, magnify=True] analytic/quad light_frac(r=1.168): 0.5000, galsim light_frac(r=1.168): 0.5000
# [e=0.405, magnify=True] analytic/quad light_frac(r=1.173): 0.5000, galsim light_frac(r=1.173): 0.5000
# [e=0.409, magnify=True] analytic/quad light_frac(r=1.179): 0.5000, galsim light_frac(r=1.179): 0.5000
# [e=0.414, magnify=True] analytic/quad light_frac(r=1.184): 0.5000, galsim light_frac(r=1.184): 0.4999
# [e=0.419, magnify=True] analytic/quad light_frac(r=1.190): 0.5000, galsim light_frac(r=1.190): 0.5000
# [e=0.424, magnify=True] analytic/quad light_frac(r=1.195): 0.5000, galsim light_frac(r=1.195): 0.5000
# [e=0.429, magnify=True] analytic/quad light_frac(r=1.201): 0.5000, galsim light_frac(r=1.201): 0.5000
# [e=0.434, magnify=True] analytic/quad light_frac(r=1.207): 0.5000, galsim light_frac(r=1.207): 0.5000
# [e=0.439, magnify=True] analytic/quad light_frac(r=1.213): 0.5000, galsim light_frac(r=1.213): 0.5000
# [e=0.444, magnify=True] analytic/quad light_frac(r=1.220): 0.5000, galsim light_frac(r=1.219): 0.5000
# [e=0.448, magnify=True] analytic/quad light_frac(r=1.226): 0.5000, galsim light_frac(r=1.226): 0.5000
# [e=0.453, magnify=True] analytic/quad light_frac(r=1.233): 0.5000, galsim light_frac(r=1.233): 0.5000
# [e=0.458, magnify=True] analytic/quad light_frac(r=1.239): 0.5000, galsim light_frac(r=1.239): 0.5000
# [e=0.463, magnify=True] analytic/quad light_frac(r=1.246): 0.5000, galsim light_frac(r=1.246): 0.5001
# [e=0.468, magnify=True] analytic/quad light_frac(r=1.253): 0.5000, galsim light_frac(r=1.253): 0.5000
# [e=0.473, magnify=True] analytic/quad light_frac(r=1.261): 0.5000, galsim light_frac(r=1.261): 0.5000
# [e=0.478, magnify=True] analytic/quad light_frac(r=1.268): 0.5000, galsim light_frac(r=1.268): 0.5001
# [e=0.483, magnify=True] analytic/quad light_frac(r=1.276): 0.5000, galsim light_frac(r=1.276): 0.5001
# [e=0.487, magnify=True] analytic/quad light_frac(r=1.284): 0.5000, galsim light_frac(r=1.284): 0.5000
# [e=0.492, magnify=True] analytic/quad light_frac(r=1.292): 0.5000, galsim light_frac(r=1.292): 0.5000
# [e=0.497, magnify=True] analytic/quad light_frac(r=1.300): 0.5000, galsim light_frac(r=1.300): 0.5000
# [e=0.502, magnify=True] analytic/quad light_frac(r=1.309): 0.5000, galsim light_frac(r=1.309): 0.5000
# [e=0.507, magnify=True] analytic/quad light_frac(r=1.317): 0.5000, galsim light_frac(r=1.317): 0.5000
# [e=0.512, magnify=True] analytic/quad light_frac(r=1.326): 0.5000, galsim light_frac(r=1.326): 0.5000
# [e=0.517, magnify=True] analytic/quad light_frac(r=1.336): 0.5000, galsim light_frac(r=1.336): 0.5000
# [e=0.522, magnify=True] analytic/quad light_frac(r=1.345): 0.5000, galsim light_frac(r=1.345): 0.4999
# [e=0.526, magnify=True] analytic/quad light_frac(r=1.355): 0.5000, galsim light_frac(r=1.355): 0.5000
# [e=0.531, magnify=True] analytic/quad light_frac(r=1.365): 0.5000, galsim light_frac(r=1.365): 0.5000
# [e=0.536, magnify=True] analytic/quad light_frac(r=1.375): 0.5000, galsim light_frac(r=1.375): 0.5001
# [e=0.541, magnify=True] analytic/quad light_frac(r=1.386): 0.5000, galsim light_frac(r=1.386): 0.5000
# [e=0.546, magnify=True] analytic/quad light_frac(r=1.397): 0.5000, galsim light_frac(r=1.397): 0.5001
# [e=0.551, magnify=True] analytic/quad light_frac(r=1.408): 0.5000, galsim light_frac(r=1.408): 0.5000
# [e=0.556, magnify=True] analytic/quad light_frac(r=1.419): 0.5000, galsim light_frac(r=1.419): 0.5000
# [e=0.561, magnify=True] analytic/quad light_frac(r=1.431): 0.5000, galsim light_frac(r=1.431): 0.5000
# [e=0.565, magnify=True] analytic/quad light_frac(r=1.443): 0.5000, galsim light_frac(r=1.443): 0.5000
# [e=0.570, magnify=True] analytic/quad light_frac(r=1.456): 0.5000, galsim light_frac(r=1.456): 0.5000
# [e=0.575, magnify=True] analytic/quad light_frac(r=1.469): 0.5000, galsim light_frac(r=1.468): 0.5000
# [e=0.580, magnify=True] analytic/quad light_frac(r=1.482): 0.5000, galsim light_frac(r=1.482): 0.5000
# [e=0.585, magnify=True] analytic/quad light_frac(r=1.495): 0.5000, galsim light_frac(r=1.496): 0.5000
# [e=0.590, magnify=True] analytic/quad light_frac(r=1.510): 0.5000, galsim light_frac(r=1.509): 0.5000
# [e=0.595, magnify=True] analytic/quad light_frac(r=1.524): 0.5000, galsim light_frac(r=1.524): 0.5000
# [e=0.600, magnify=True] analytic/quad light_frac(r=1.539): 0.5000, galsim light_frac(r=1.539): 0.5000
# [e=0.604, magnify=True] analytic/quad light_frac(r=1.554): 0.5000, galsim light_frac(r=1.554): 0.4999
# [e=0.609, magnify=True] analytic/quad light_frac(r=1.570): 0.5000, galsim light_frac(r=1.570): 0.5000
# [e=0.614, magnify=True] analytic/quad light_frac(r=1.586): 0.5000, galsim light_frac(r=1.586): 0.5000
# [e=0.619, magnify=True] analytic/quad light_frac(r=1.603): 0.5000, galsim light_frac(r=1.603): 0.5000
# [e=0.624, magnify=True] analytic/quad light_frac(r=1.621): 0.5000, galsim light_frac(r=1.621): 0.5000
# [e=0.629, magnify=True] analytic/quad light_frac(r=1.638): 0.5000, galsim light_frac(r=1.638): 0.5000
# [e=0.634, magnify=True] analytic/quad light_frac(r=1.657): 0.5000, galsim light_frac(r=1.657): 0.5000
# [e=0.639, magnify=True] analytic/quad light_frac(r=1.676): 0.5000, galsim light_frac(r=1.676): 0.5000
# [e=0.643, magnify=True] analytic/quad light_frac(r=1.696): 0.5000, galsim light_frac(r=1.696): 0.5000
# [e=0.648, magnify=True] analytic/quad light_frac(r=1.716): 0.5000, galsim light_frac(r=1.716): 0.5000
# [e=0.653, magnify=True] analytic/quad light_frac(r=1.737): 0.5000, galsim light_frac(r=1.737): 0.5000
# [e=0.658, magnify=True] analytic/quad light_frac(r=1.758): 0.5000, galsim light_frac(r=1.759): 0.5000
# [e=0.663, magnify=True] analytic/quad light_frac(r=1.781): 0.5000, galsim light_frac(r=1.781): 0.5000
# [e=0.668, magnify=True] analytic/quad light_frac(r=1.804): 0.5000, galsim light_frac(r=1.804): 0.5000
# [e=0.673, magnify=True] analytic/quad light_frac(r=1.828): 0.5000, galsim light_frac(r=1.828): 0.5000
# [e=0.678, magnify=True] analytic/quad light_frac(r=1.852): 0.5000, galsim light_frac(r=1.852): 0.5000
# [e=0.682, magnify=True] analytic/quad light_frac(r=1.878): 0.5000, galsim light_frac(r=1.878): 0.5000
# [e=0.687, magnify=True] analytic/quad light_frac(r=1.904): 0.5000, galsim light_frac(r=1.904): 0.5000
# [e=0.692, magnify=True] analytic/quad light_frac(r=1.932): 0.5000, galsim light_frac(r=1.932): 0.5000
# [e=0.697, magnify=True] analytic/quad light_frac(r=1.960): 0.5000, galsim light_frac(r=1.960): 0.5000
# [e=0.702, magnify=True] analytic/quad light_frac(r=1.989): 0.5000, galsim light_frac(r=1.989): 0.5000
# [e=0.707, magnify=True] analytic/quad light_frac(r=2.020): 0.5000, galsim light_frac(r=2.019): 0.5000
# [e=0.712, magnify=True] analytic/quad light_frac(r=2.051): 0.5000, galsim light_frac(r=2.051): 0.5000
# [e=0.717, magnify=True] analytic/quad light_frac(r=2.084): 0.5000, galsim light_frac(r=2.083): 0.5000
# [e=0.721, magnify=True] analytic/quad light_frac(r=2.117): 0.5000, galsim light_frac(r=2.118): 0.5001
# [e=0.726, magnify=True] analytic/quad light_frac(r=2.153): 0.5000, galsim light_frac(r=2.153): 0.5001
# [e=0.731, magnify=True] analytic/quad light_frac(r=2.189): 0.5000, galsim light_frac(r=2.189): 0.5000
# [e=0.736, magnify=True] analytic/quad light_frac(r=2.227): 0.5000, galsim light_frac(r=2.227): 0.5000
# [e=0.741, magnify=True] analytic/quad light_frac(r=2.266): 0.5000, galsim light_frac(r=2.266): 0.5000
# [e=0.746, magnify=True] analytic/quad light_frac(r=2.307): 0.5000, galsim light_frac(r=2.307): 0.5000
# [e=0.751, magnify=True] analytic/quad light_frac(r=2.350): 0.5000, galsim light_frac(r=2.350): 0.5000
# [e=0.756, magnify=True] analytic/quad light_frac(r=2.394): 0.5000, galsim light_frac(r=2.394): 0.5000
# [e=0.760, magnify=True] analytic/quad light_frac(r=2.441): 0.5000, galsim light_frac(r=2.441): 0.5000
# [e=0.765, magnify=True] analytic/quad light_frac(r=2.489): 0.5000, galsim light_frac(r=2.489): 0.5000
# [e=0.770, magnify=True] analytic/quad light_frac(r=2.539): 0.5000, galsim light_frac(r=2.539): 0.5000
# [e=0.775, magnify=True] analytic/quad light_frac(r=2.592): 0.5000, galsim light_frac(r=2.592): 0.5000
# [e=0.780, magnify=True] analytic/quad light_frac(r=2.647): 0.5000, galsim light_frac(r=2.647): 0.5000
# [e=0.785, magnify=True] analytic/quad light_frac(r=2.705): 0.5000, galsim light_frac(r=2.705): 0.5000
# [e=0.790, magnify=True] analytic/quad light_frac(r=2.765): 0.5000, galsim light_frac(r=2.765): 0.5000
# [e=0.795, magnify=True] analytic/quad light_frac(r=2.829): 0.5000, galsim light_frac(r=2.829): 0.5000
# [e=0.799, magnify=True] analytic/quad light_frac(r=2.895): 0.5000, galsim light_frac(r=2.895): 0.5000
# [e=0.804, magnify=True] analytic/quad light_frac(r=2.965): 0.5000, galsim light_frac(r=2.965): 0.5000
# [e=0.809, magnify=True] analytic/quad light_frac(r=3.039): 0.5000, galsim light_frac(r=3.039): 0.5000
# [e=0.814, magnify=True] analytic/quad light_frac(r=3.116): 0.5000, galsim light_frac(r=3.116): 0.5000
# [e=0.819, magnify=True] analytic/quad light_frac(r=3.198): 0.5000, galsim light_frac(r=3.198): 0.5000
# [e=0.824, magnify=True] analytic/quad light_frac(r=3.284): 0.5000, galsim light_frac(r=3.284): 0.5000
# [e=0.829, magnify=True] analytic/quad light_frac(r=3.376): 0.5000, galsim light_frac(r=3.376): 0.5000
# [e=0.834, magnify=True] analytic/quad light_frac(r=3.472): 0.5000, galsim light_frac(r=3.472): 0.5000
# [e=0.838, magnify=True] analytic/quad light_frac(r=3.575): 0.5000, galsim light_frac(r=3.575): 0.5000
# [e=0.843, magnify=True] analytic/quad light_frac(r=3.684): 0.5000, galsim light_frac(r=3.684): 0.5000
# [e=0.848, magnify=True] analytic/quad light_frac(r=3.800): 0.5000, galsim light_frac(r=3.800): 0.5000
# [e=0.853, magnify=True] analytic/quad light_frac(r=3.925): 0.5000, galsim light_frac(r=3.924): 0.5000
# [e=0.858, magnify=True] analytic/quad light_frac(r=4.057): 0.5000, galsim light_frac(r=4.057): 0.5000
# [e=0.863, magnify=True] analytic/quad light_frac(r=4.199): 0.5000, galsim light_frac(r=4.199): 0.5000
# [e=0.868, magnify=True] analytic/quad light_frac(r=4.352): 0.5000, galsim light_frac(r=4.352): 0.5000
# [e=0.873, magnify=True] analytic/quad light_frac(r=4.516): 0.5000, galsim light_frac(r=4.516): 0.5000
# [e=0.877, magnify=True] analytic/quad light_frac(r=4.694): 0.5000, galsim light_frac(r=4.694): 0.5000
# [e=0.882, magnify=True] analytic/quad light_frac(r=4.887): 0.5000, galsim light_frac(r=4.886): 0.5000
# [e=0.887, magnify=True] analytic/quad light_frac(r=5.096): 0.5000, galsim light_frac(r=5.096): 0.5000
# [e=0.892, magnify=True] analytic/quad light_frac(r=5.324): 0.5000, galsim light_frac(r=5.324): 0.5000
# [e=0.897, magnify=True] analytic/quad light_frac(r=5.574): 0.5000, galsim light_frac(r=5.574): 0.5000
# [e=0.902, magnify=True] analytic/quad light_frac(r=5.848): 0.5000, galsim light_frac(r=5.848): 0.5000
# [e=0.907, magnify=True] analytic/quad light_frac(r=6.152): 0.5000, galsim light_frac(r=6.152): 0.5000
# [e=0.912, magnify=True] analytic/quad light_frac(r=6.489): 0.5000, galsim light_frac(r=6.489): 0.5000
# [e=0.916, magnify=True] analytic/quad light_frac(r=6.865): 0.5000, galsim light_frac(r=6.865): 0.5000
# [e=0.921, magnify=True] analytic/quad light_frac(r=7.288): 0.5000, galsim light_frac(r=7.288): 0.5000
# [e=0.926, magnify=True] analytic/quad light_frac(r=7.768): 0.5000, galsim light_frac(r=7.768): 0.5000
# [e=0.931, magnify=True] analytic/quad light_frac(r=8.315): 0.5000, galsim light_frac(r=8.314): 0.5000
# [e=0.936, magnify=True] analytic/quad light_frac(r=8.945): 0.5000, galsim light_frac(r=8.945): 0.5000
# [e=0.941, magnify=True] analytic/quad light_frac(r=9.679): 0.5000, galsim light_frac(r=9.679): 0.5000
# [e=0.946, magnify=True] analytic/quad light_frac(r=10.545): 0.5000, galsim light_frac(r=10.545): 0.5000
# [e=0.951, magnify=True] analytic/quad light_frac(r=11.582): 0.5000, galsim light_frac(r=11.582): 0.5000
# [e=0.955, magnify=True] analytic/quad light_frac(r=12.845): 0.5000, galsim light_frac(r=12.845): 0.5000
# [e=0.960, magnify=True] analytic/quad light_frac(r=14.419): 0.5000, galsim light_frac(r=14.419): 0.5000
# [e=0.965, magnify=True] analytic/quad light_frac(r=16.432): 0.5000, galsim light_frac(r=16.432): 0.5000
# /usr/local/anaconda3/lib/python3.7/site-packages/galsim/image.py:1446: RuntimeWarning: invalid value encountered in sqrt
#   hlr = np.sqrt(hlrsq) * self.scale
# [e=0.970, magnify=True] analytic/quad light_frac(r=19.100): 0.5000, galsim light_frac(r=nan): 0.0000
# [e=0.000, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.005, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.010, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.015, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.019, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.024, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.029, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.034, magnify=False] analytic/quad light_frac(r=1.000): 0.5000, galsim light_frac(r=1.000): 0.5000
# [e=0.039, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.044, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.049, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.054, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.058, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.001): 0.5000
# [e=0.063, magnify=False] analytic/quad light_frac(r=1.001): 0.5000, galsim light_frac(r=1.002): 0.5001
# [e=0.068, magnify=False] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.073, magnify=False] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.078, magnify=False] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.4999
# [e=0.083, magnify=False] analytic/quad light_frac(r=1.002): 0.5000, galsim light_frac(r=1.002): 0.5000
# [e=0.088, magnify=False] analytic/quad light_frac(r=1.003): 0.5000, galsim light_frac(r=1.003): 0.5000
# [e=0.093, magnify=False] analytic/quad light_frac(r=1.003): 0.5000, galsim light_frac(r=1.003): 0.5000
# [e=0.097, magnify=False] analytic/quad light_frac(r=1.003): 0.5000, galsim light_frac(r=1.003): 0.5000
# [e=0.102, magnify=False] analytic/quad light_frac(r=1.004): 0.5000, galsim light_frac(r=1.004): 0.4999
# [e=0.107, magnify=False] analytic/quad light_frac(r=1.004): 0.5000, galsim light_frac(r=1.004): 0.5000
# [e=0.112, magnify=False] analytic/quad light_frac(r=1.004): 0.5000, galsim light_frac(r=1.004): 0.4999
# [e=0.117, magnify=False] analytic/quad light_frac(r=1.005): 0.5000, galsim light_frac(r=1.005): 0.5000
# [e=0.122, magnify=False] analytic/quad light_frac(r=1.005): 0.5000, galsim light_frac(r=1.005): 0.5000
# [e=0.127, magnify=False] analytic/quad light_frac(r=1.006): 0.5000, galsim light_frac(r=1.006): 0.4999
# [e=0.132, magnify=False] analytic/quad light_frac(r=1.006): 0.5000, galsim light_frac(r=1.006): 0.5001
# [e=0.136, magnify=False] analytic/quad light_frac(r=1.007): 0.5000, galsim light_frac(r=1.007): 0.5001
# [e=0.141, magnify=False] analytic/quad light_frac(r=1.007): 0.5000, galsim light_frac(r=1.007): 0.5000
# [e=0.146, magnify=False] analytic/quad light_frac(r=1.008): 0.5000, galsim light_frac(r=1.008): 0.5001
# [e=0.151, magnify=False] analytic/quad light_frac(r=1.008): 0.5000, galsim light_frac(r=1.008): 0.5001
# [e=0.156, magnify=False] analytic/quad light_frac(r=1.009): 0.5000, galsim light_frac(r=1.009): 0.5000
# [e=0.161, magnify=False] analytic/quad light_frac(r=1.009): 0.5000, galsim light_frac(r=1.009): 0.4999
# [e=0.166, magnify=False] analytic/quad light_frac(r=1.010): 0.5000, galsim light_frac(r=1.010): 0.5000
# [e=0.171, magnify=False] analytic/quad light_frac(r=1.011): 0.5000, galsim light_frac(r=1.010): 0.5000
# [e=0.175, magnify=False] analytic/quad light_frac(r=1.011): 0.5000, galsim light_frac(r=1.011): 0.5000
# [e=0.180, magnify=False] analytic/quad light_frac(r=1.012): 0.5000, galsim light_frac(r=1.012): 0.5000
# [e=0.185, magnify=False] analytic/quad light_frac(r=1.012): 0.5000, galsim light_frac(r=1.012): 0.5000
# [e=0.190, magnify=False] analytic/quad light_frac(r=1.013): 0.5000, galsim light_frac(r=1.013): 0.5000
# [e=0.195, magnify=False] analytic/quad light_frac(r=1.014): 0.5000, galsim light_frac(r=1.014): 0.5000
# [e=0.200, magnify=False] analytic/quad light_frac(r=1.015): 0.5000, galsim light_frac(r=1.015): 0.5000
# [e=0.205, magnify=False] analytic/quad light_frac(r=1.015): 0.5000, galsim light_frac(r=1.015): 0.5000
# [e=0.210, magnify=False] analytic/quad light_frac(r=1.016): 0.5000, galsim light_frac(r=1.016): 0.5000
# [e=0.214, magnify=False] analytic/quad light_frac(r=1.017): 0.5000, galsim light_frac(r=1.017): 0.5001
# [e=0.219, magnify=False] analytic/quad light_frac(r=1.018): 0.5000, galsim light_frac(r=1.018): 0.5000
# [e=0.224, magnify=False] analytic/quad light_frac(r=1.019): 0.5000, galsim light_frac(r=1.019): 0.5000
# [e=0.229, magnify=False] analytic/quad light_frac(r=1.020): 0.5000, galsim light_frac(r=1.020): 0.4999
# [e=0.234, magnify=False] analytic/quad light_frac(r=1.021): 0.5000, galsim light_frac(r=1.021): 0.5001
# [e=0.239, magnify=False] analytic/quad light_frac(r=1.021): 0.5000, galsim light_frac(r=1.022): 0.5001
# [e=0.244, magnify=False] analytic/quad light_frac(r=1.022): 0.5000, galsim light_frac(r=1.022): 0.5000
# [e=0.249, magnify=False] analytic/quad light_frac(r=1.023): 0.5000, galsim light_frac(r=1.023): 0.5000
# [e=0.253, magnify=False] analytic/quad light_frac(r=1.024): 0.5000, galsim light_frac(r=1.024): 0.4999
# [e=0.258, magnify=False] analytic/quad light_frac(r=1.025): 0.5000, galsim light_frac(r=1.025): 0.5000
# [e=0.263, magnify=False] analytic/quad light_frac(r=1.027): 0.5000, galsim light_frac(r=1.027): 0.5000
# [e=0.268, magnify=False] analytic/quad light_frac(r=1.028): 0.5000, galsim light_frac(r=1.028): 0.5000
# [e=0.273, magnify=False] analytic/quad light_frac(r=1.029): 0.5000, galsim light_frac(r=1.029): 0.5000
# [e=0.278, magnify=False] analytic/quad light_frac(r=1.030): 0.5000, galsim light_frac(r=1.030): 0.5000
# [e=0.283, magnify=False] analytic/quad light_frac(r=1.031): 0.5000, galsim light_frac(r=1.031): 0.5001
# [e=0.288, magnify=False] analytic/quad light_frac(r=1.032): 0.5000, galsim light_frac(r=1.032): 0.5000
# [e=0.292, magnify=False] analytic/quad light_frac(r=1.034): 0.5000, galsim light_frac(r=1.034): 0.5000
# [e=0.297, magnify=False] analytic/quad light_frac(r=1.035): 0.5000, galsim light_frac(r=1.035): 0.5000
# [e=0.302, magnify=False] analytic/quad light_frac(r=1.036): 0.5000, galsim light_frac(r=1.036): 0.5000
# [e=0.307, magnify=False] analytic/quad light_frac(r=1.038): 0.5000, galsim light_frac(r=1.038): 0.5000
# [e=0.312, magnify=False] analytic/quad light_frac(r=1.039): 0.5000, galsim light_frac(r=1.039): 0.5000
# [e=0.317, magnify=False] analytic/quad light_frac(r=1.040): 0.5000, galsim light_frac(r=1.040): 0.5000
# [e=0.322, magnify=False] analytic/quad light_frac(r=1.042): 0.5000, galsim light_frac(r=1.042): 0.5000
# [e=0.327, magnify=False] analytic/quad light_frac(r=1.043): 0.5000, galsim light_frac(r=1.043): 0.4999
# [e=0.331, magnify=False] analytic/quad light_frac(r=1.045): 0.5000, galsim light_frac(r=1.045): 0.4999
# [e=0.336, magnify=False] analytic/quad light_frac(r=1.046): 0.5000, galsim light_frac(r=1.047): 0.5001
# [e=0.341, magnify=False] analytic/quad light_frac(r=1.048): 0.5000, galsim light_frac(r=1.048): 0.5000
# [e=0.346, magnify=False] analytic/quad light_frac(r=1.050): 0.5000, galsim light_frac(r=1.050): 0.5000
# [e=0.351, magnify=False] analytic/quad light_frac(r=1.051): 0.5000, galsim light_frac(r=1.051): 0.5000
# [e=0.356, magnify=False] analytic/quad light_frac(r=1.053): 0.5000, galsim light_frac(r=1.053): 0.5000
# [e=0.361, magnify=False] analytic/quad light_frac(r=1.055): 0.5000, galsim light_frac(r=1.055): 0.4999
# [e=0.366, magnify=False] analytic/quad light_frac(r=1.057): 0.5000, galsim light_frac(r=1.057): 0.5000
# [e=0.370, magnify=False] analytic/quad light_frac(r=1.059): 0.5000, galsim light_frac(r=1.059): 0.5000
# [e=0.375, magnify=False] analytic/quad light_frac(r=1.061): 0.5000, galsim light_frac(r=1.060): 0.5000
# [e=0.380, magnify=False] analytic/quad light_frac(r=1.062): 0.5000, galsim light_frac(r=1.063): 0.5000
# [e=0.385, magnify=False] analytic/quad light_frac(r=1.064): 0.5000, galsim light_frac(r=1.064): 0.5000
# [e=0.390, magnify=False] analytic/quad light_frac(r=1.067): 0.5000, galsim light_frac(r=1.067): 0.5000
# [e=0.395, magnify=False] analytic/quad light_frac(r=1.069): 0.5000, galsim light_frac(r=1.069): 0.4999
# [e=0.400, magnify=False] analytic/quad light_frac(r=1.071): 0.5000, galsim light_frac(r=1.071): 0.5000
# [e=0.405, magnify=False] analytic/quad light_frac(r=1.073): 0.5000, galsim light_frac(r=1.073): 0.5000
# [e=0.409, magnify=False] analytic/quad light_frac(r=1.075): 0.5000, galsim light_frac(r=1.075): 0.5000
# [e=0.414, magnify=False] analytic/quad light_frac(r=1.078): 0.5000, galsim light_frac(r=1.078): 0.5001
# [e=0.419, magnify=False] analytic/quad light_frac(r=1.080): 0.5000, galsim light_frac(r=1.080): 0.4999
# [e=0.424, magnify=False] analytic/quad light_frac(r=1.083): 0.5000, galsim light_frac(r=1.083): 0.5000
# [e=0.429, magnify=False] analytic/quad light_frac(r=1.085): 0.5000, galsim light_frac(r=1.085): 0.5000
# [e=0.434, magnify=False] analytic/quad light_frac(r=1.088): 0.5000, galsim light_frac(r=1.088): 0.5000
# [e=0.439, magnify=False] analytic/quad light_frac(r=1.090): 0.5000, galsim light_frac(r=1.090): 0.5000
# [e=0.444, magnify=False] analytic/quad light_frac(r=1.093): 0.5000, galsim light_frac(r=1.093): 0.5000
# [e=0.448, magnify=False] analytic/quad light_frac(r=1.096): 0.5000, galsim light_frac(r=1.096): 0.4999
# [e=0.453, magnify=False] analytic/quad light_frac(r=1.099): 0.5000, galsim light_frac(r=1.099): 0.5000
# [e=0.458, magnify=False] analytic/quad light_frac(r=1.102): 0.5000, galsim light_frac(r=1.102): 0.5000
# [e=0.463, magnify=False] analytic/quad light_frac(r=1.105): 0.5000, galsim light_frac(r=1.104): 0.4999
# [e=0.468, magnify=False] analytic/quad light_frac(r=1.108): 0.5000, galsim light_frac(r=1.108): 0.5000
# [e=0.473, magnify=False] analytic/quad light_frac(r=1.111): 0.5000, galsim light_frac(r=1.111): 0.5000
# [e=0.478, magnify=False] analytic/quad light_frac(r=1.114): 0.5000, galsim light_frac(r=1.114): 0.5000
# [e=0.483, magnify=False] analytic/quad light_frac(r=1.117): 0.5000, galsim light_frac(r=1.117): 0.4999
# [e=0.487, magnify=False] analytic/quad light_frac(r=1.121): 0.5000, galsim light_frac(r=1.121): 0.5000
# [e=0.492, magnify=False] analytic/quad light_frac(r=1.124): 0.5000, galsim light_frac(r=1.124): 0.4999
# [e=0.497, magnify=False] analytic/quad light_frac(r=1.128): 0.5000, galsim light_frac(r=1.128): 0.5001
# [e=0.502, magnify=False] analytic/quad light_frac(r=1.132): 0.5000, galsim light_frac(r=1.132): 0.5000
# [e=0.507, magnify=False] analytic/quad light_frac(r=1.136): 0.5000, galsim light_frac(r=1.136): 0.5000
# [e=0.512, magnify=False] analytic/quad light_frac(r=1.140): 0.5000, galsim light_frac(r=1.139): 0.5000
# [e=0.517, magnify=False] analytic/quad light_frac(r=1.144): 0.5000, galsim light_frac(r=1.143): 0.5000
# [e=0.522, magnify=False] analytic/quad light_frac(r=1.148): 0.5000, galsim light_frac(r=1.148): 0.5000
# [e=0.526, magnify=False] analytic/quad light_frac(r=1.152): 0.5000, galsim light_frac(r=1.152): 0.5000
# [e=0.531, magnify=False] analytic/quad light_frac(r=1.156): 0.5000, galsim light_frac(r=1.156): 0.5001
# [e=0.536, magnify=False] analytic/quad light_frac(r=1.161): 0.5000, galsim light_frac(r=1.161): 0.5000
# [e=0.541, magnify=False] analytic/quad light_frac(r=1.165): 0.5000, galsim light_frac(r=1.165): 0.4999
# [e=0.546, magnify=False] analytic/quad light_frac(r=1.170): 0.5000, galsim light_frac(r=1.170): 0.4999
# [e=0.551, magnify=False] analytic/quad light_frac(r=1.175): 0.5000, galsim light_frac(r=1.175): 0.5000
# [e=0.556, magnify=False] analytic/quad light_frac(r=1.180): 0.5000, galsim light_frac(r=1.180): 0.5000
# [e=0.561, magnify=False] analytic/quad light_frac(r=1.185): 0.5000, galsim light_frac(r=1.185): 0.5000
# [e=0.565, magnify=False] analytic/quad light_frac(r=1.190): 0.5000, galsim light_frac(r=1.190): 0.4999
# [e=0.570, magnify=False] analytic/quad light_frac(r=1.196): 0.5000, galsim light_frac(r=1.196): 0.5000
# [e=0.575, magnify=False] analytic/quad light_frac(r=1.201): 0.5000, galsim light_frac(r=1.201): 0.5000
# [e=0.580, magnify=False] analytic/quad light_frac(r=1.207): 0.5000, galsim light_frac(r=1.207): 0.5000
# [e=0.585, magnify=False] analytic/quad light_frac(r=1.213): 0.5000, galsim light_frac(r=1.213): 0.5000
# [e=0.590, magnify=False] analytic/quad light_frac(r=1.219): 0.5000, galsim light_frac(r=1.219): 0.5000
# [e=0.595, magnify=False] analytic/quad light_frac(r=1.225): 0.5000, galsim light_frac(r=1.225): 0.5000
# [e=0.600, magnify=False] analytic/quad light_frac(r=1.232): 0.5000, galsim light_frac(r=1.232): 0.5000
# [e=0.604, magnify=False] analytic/quad light_frac(r=1.238): 0.5000, galsim light_frac(r=1.238): 0.5001
# [e=0.609, magnify=False] analytic/quad light_frac(r=1.245): 0.5000, galsim light_frac(r=1.245): 0.5000
# [e=0.614, magnify=False] analytic/quad light_frac(r=1.252): 0.5000, galsim light_frac(r=1.252): 0.5000
# [e=0.619, magnify=False] analytic/quad light_frac(r=1.259): 0.5000, galsim light_frac(r=1.259): 0.5000
# [e=0.624, magnify=False] analytic/quad light_frac(r=1.266): 0.5000, galsim light_frac(r=1.267): 0.5001
# [e=0.629, magnify=False] analytic/quad light_frac(r=1.274): 0.5000, galsim light_frac(r=1.274): 0.5000
# [e=0.634, magnify=False] analytic/quad light_frac(r=1.282): 0.5000, galsim light_frac(r=1.282): 0.5000
# [e=0.639, magnify=False] analytic/quad light_frac(r=1.290): 0.5000, galsim light_frac(r=1.290): 0.5000
# [e=0.643, magnify=False] analytic/quad light_frac(r=1.298): 0.5000, galsim light_frac(r=1.298): 0.5000
# [e=0.648, magnify=False] analytic/quad light_frac(r=1.306): 0.5000, galsim light_frac(r=1.306): 0.5000
# [e=0.653, magnify=False] analytic/quad light_frac(r=1.315): 0.5000, galsim light_frac(r=1.315): 0.5000
# [e=0.658, magnify=False] analytic/quad light_frac(r=1.324): 0.5000, galsim light_frac(r=1.324): 0.5000
# [e=0.663, magnify=False] analytic/quad light_frac(r=1.333): 0.5000, galsim light_frac(r=1.333): 0.5000
# [e=0.668, magnify=False] analytic/quad light_frac(r=1.343): 0.5000, galsim light_frac(r=1.343): 0.5001
# [e=0.673, magnify=False] analytic/quad light_frac(r=1.352): 0.5000, galsim light_frac(r=1.353): 0.5001
# [e=0.678, magnify=False] analytic/quad light_frac(r=1.362): 0.5000, galsim light_frac(r=1.362): 0.5000
# [e=0.682, magnify=False] analytic/quad light_frac(r=1.373): 0.5000, galsim light_frac(r=1.373): 0.5000
# [e=0.687, magnify=False] analytic/quad light_frac(r=1.383): 0.5000, galsim light_frac(r=1.383): 0.5000
# [e=0.692, magnify=False] analytic/quad light_frac(r=1.394): 0.5000, galsim light_frac(r=1.394): 0.5000
# [e=0.697, magnify=False] analytic/quad light_frac(r=1.405): 0.5000, galsim light_frac(r=1.405): 0.5000
# [e=0.702, magnify=False] analytic/quad light_frac(r=1.417): 0.5000, galsim light_frac(r=1.417): 0.5001
# [e=0.707, magnify=False] analytic/quad light_frac(r=1.429): 0.5000, galsim light_frac(r=1.429): 0.5000
# [e=0.712, magnify=False] analytic/quad light_frac(r=1.441): 0.5000, galsim light_frac(r=1.441): 0.5000
# [e=0.717, magnify=False] analytic/quad light_frac(r=1.453): 0.5000, galsim light_frac(r=1.453): 0.5000
# [e=0.721, magnify=False] analytic/quad light_frac(r=1.466): 0.5000, galsim light_frac(r=1.467): 0.5001
# [e=0.726, magnify=False] analytic/quad light_frac(r=1.480): 0.5000, galsim light_frac(r=1.480): 0.5000
# [e=0.731, magnify=False] analytic/quad light_frac(r=1.493): 0.5000, galsim light_frac(r=1.493): 0.5000
# [e=0.736, magnify=False] analytic/quad light_frac(r=1.507): 0.5000, galsim light_frac(r=1.508): 0.5000
# [e=0.741, magnify=False] analytic/quad light_frac(r=1.522): 0.5000, galsim light_frac(r=1.522): 0.5001
# [e=0.746, magnify=False] analytic/quad light_frac(r=1.537): 0.5000, galsim light_frac(r=1.537): 0.5001
# [e=0.751, magnify=False] analytic/quad light_frac(r=1.553): 0.5000, galsim light_frac(r=1.553): 0.5000
# [e=0.756, magnify=False] analytic/quad light_frac(r=1.569): 0.5000, galsim light_frac(r=1.569): 0.5000
# [e=0.760, magnify=False] analytic/quad light_frac(r=1.585): 0.5000, galsim light_frac(r=1.585): 0.4999
# [e=0.765, magnify=False] analytic/quad light_frac(r=1.602): 0.5000, galsim light_frac(r=1.602): 0.5000
# [e=0.770, magnify=False] analytic/quad light_frac(r=1.620): 0.5000, galsim light_frac(r=1.620): 0.4999
# [e=0.775, magnify=False] analytic/quad light_frac(r=1.638): 0.5000, galsim light_frac(r=1.638): 0.5000
# [e=0.780, magnify=False] analytic/quad light_frac(r=1.657): 0.5000, galsim light_frac(r=1.657): 0.5000
# [e=0.785, magnify=False] analytic/quad light_frac(r=1.676): 0.5000, galsim light_frac(r=1.677): 0.5000
# [e=0.790, magnify=False] analytic/quad light_frac(r=1.697): 0.5000, galsim light_frac(r=1.697): 0.5000
# [e=0.795, magnify=False] analytic/quad light_frac(r=1.718): 0.5000, galsim light_frac(r=1.718): 0.5000
# [e=0.799, magnify=False] analytic/quad light_frac(r=1.739): 0.5000, galsim light_frac(r=1.739): 0.5000
# [e=0.804, magnify=False] analytic/quad light_frac(r=1.762): 0.5000, galsim light_frac(r=1.762): 0.5000
# [e=0.809, magnify=False] analytic/quad light_frac(r=1.786): 0.5000, galsim light_frac(r=1.786): 0.5000
# [e=0.814, magnify=False] analytic/quad light_frac(r=1.810): 0.5000, galsim light_frac(r=1.810): 0.5000
# [e=0.819, magnify=False] analytic/quad light_frac(r=1.835): 0.5000, galsim light_frac(r=1.835): 0.5000
# [e=0.824, magnify=False] analytic/quad light_frac(r=1.862): 0.5000, galsim light_frac(r=1.862): 0.5000
# [e=0.829, magnify=False] analytic/quad light_frac(r=1.890): 0.5000, galsim light_frac(r=1.889): 0.4999
# [e=0.834, magnify=False] analytic/quad light_frac(r=1.918): 0.5000, galsim light_frac(r=1.919): 0.5000
# [e=0.838, magnify=False] analytic/quad light_frac(r=1.949): 0.5000, galsim light_frac(r=1.949): 0.5000
# [e=0.843, magnify=False] analytic/quad light_frac(r=1.980): 0.5000, galsim light_frac(r=1.980): 0.5000
# [e=0.848, magnify=False] analytic/quad light_frac(r=2.013): 0.5000, galsim light_frac(r=2.013): 0.5000
# [e=0.853, magnify=False] analytic/quad light_frac(r=2.048): 0.5000, galsim light_frac(r=2.048): 0.5000
# [e=0.858, magnify=False] analytic/quad light_frac(r=2.085): 0.5000, galsim light_frac(r=2.085): 0.5000
# [e=0.863, magnify=False] analytic/quad light_frac(r=2.123): 0.5000, galsim light_frac(r=2.123): 0.5000
# [e=0.868, magnify=False] analytic/quad light_frac(r=2.164): 0.5000, galsim light_frac(r=2.164): 0.5000
# [e=0.873, magnify=False] analytic/quad light_frac(r=2.207): 0.5000, galsim light_frac(r=2.207): 0.5000
# [e=0.877, magnify=False] analytic/quad light_frac(r=2.252): 0.5000, galsim light_frac(r=2.253): 0.5001
# [e=0.882, magnify=False] analytic/quad light_frac(r=2.300): 0.5000, galsim light_frac(r=2.300): 0.5000
# [e=0.887, magnify=False] analytic/quad light_frac(r=2.352): 0.5000, galsim light_frac(r=2.352): 0.5000
# [e=0.892, magnify=False] analytic/quad light_frac(r=2.406): 0.5000, galsim light_frac(r=2.406): 0.5000
# [e=0.897, magnify=False] analytic/quad light_frac(r=2.465): 0.5000, galsim light_frac(r=2.465): 0.5000
# [e=0.902, magnify=False] analytic/quad light_frac(r=2.528): 0.5000, galsim light_frac(r=2.528): 0.5000
# [e=0.907, magnify=False] analytic/quad light_frac(r=2.596): 0.5000, galsim light_frac(r=2.596): 0.5000
# [e=0.912, magnify=False] analytic/quad light_frac(r=2.669): 0.5000, galsim light_frac(r=2.669): 0.5000
# [e=0.916, magnify=False] analytic/quad light_frac(r=2.748): 0.5000, galsim light_frac(r=2.748): 0.5000
# [e=0.921, magnify=False] analytic/quad light_frac(r=2.835): 0.5000, galsim light_frac(r=2.835): 0.5000
# [e=0.926, magnify=False] analytic/quad light_frac(r=2.930): 0.5000, galsim light_frac(r=2.930): 0.5000
# [e=0.931, magnify=False] analytic/quad light_frac(r=3.035): 0.5000, galsim light_frac(r=3.035): 0.5000
# [e=0.936, magnify=False] analytic/quad light_frac(r=3.151): 0.5000, galsim light_frac(r=3.151): 0.5000
# [e=0.941, magnify=False] analytic/quad light_frac(r=3.282): 0.5000, galsim light_frac(r=3.282): 0.5001
# [e=0.946, magnify=False] analytic/quad light_frac(r=3.430): 0.5000, galsim light_frac(r=3.430): 0.5000
# [e=0.951, magnify=False] analytic/quad light_frac(r=3.599): 0.5000, galsim light_frac(r=3.599): 0.5000
# [e=0.955, magnify=False] analytic/quad light_frac(r=3.794): 0.5000, galsim light_frac(r=3.794): 0.5000
# [e=0.960, magnify=False] analytic/quad light_frac(r=4.025): 0.5000, galsim light_frac(r=4.025): 0.5000
# [e=0.965, magnify=False] analytic/quad light_frac(r=4.302): 0.5000, galsim light_frac(r=4.302): 0.5000
# [e=0.970, magnify=False] analytic/quad light_frac(r=4.643): 0.5000, galsim light_frac(r=4.643): 0.5000

# %% [markdown]
# ## Save the training data

# %%
# Create pandas DataFrame.
df = pd.DataFrame(data)
df.to_csv('hlrshear.csv', index=False)
df
# Out:
#             e  scale_analytic_magnified  scale_galsim_magnified  \
# 0    0.000000                  1.000000                0.999992
# 1    0.004874                  1.000020                1.000009
# 2    0.009749                  1.000080                1.000071
# 3    0.014623                  1.000181                1.000177
# 4    0.019497                  1.000322                1.000294
# ..        ...                       ...                     ...
# 195  0.950503                 11.581690               11.581738
# 196  0.955377                 12.845067               12.845270
# 197  0.960251                 14.418514               14.418518
# 198  0.965126                 16.432044               16.432042
# 199  0.970000                 19.100163                     NaN
#
#      scale_wh_magnified  scale_analytic  scale_galsim  scale_wh
# 0              1.006604        1.000000      0.999992  1.006604
# 1              1.006622        1.000008      0.999995  1.006610
# 2              1.006675        1.000033      1.000026  1.006628
# 3              1.006765        1.000074      1.000068  1.006657
# 4              1.006891        1.000132      1.000148  1.006699
# ..                  ...             ...           ...       ...
# 195           11.780171        3.598627      3.598750  3.660298
# 196           13.064788        3.794299      3.794396  3.859202
# 197           14.664739        4.024742      4.024721  4.093473
# 198           16.712242        4.301698      4.301530  4.375050
# 199           19.425444        4.643344      4.643073  4.722421
#
# [200 rows x 7 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
matplotlib.rcParams.update({'font.size': 23})

fig, axs = plt.subplots(2,figsize=(15,21))
e_list_fine = np.linspace(0, 0.999, num=400, endpoint=True)

for i, magnify in enumerate([True, False]):

    postfix = '_magnified' if magnify else ''
    f = interp1d(df['e'], df['scale_analytic'+postfix], bounds_error=False, fill_value='extrapolate')
    f2 = interp1d(df['e'], df['scale_analytic'+postfix], kind='cubic', bounds_error=False, fill_value='extrapolate')
    
    axs[i].scatter(df['e'], df['scale_galsim'+postfix], marker='+', facecolors='orange', edgecolors='orange', label='GalSim', s=200, alpha=0.8)
    axs[i].scatter(df['e'], df['scale_analytic'+postfix], facecolors='red', label='Analytic/Quad', marker='+', s=50, alpha=0.8)

    axs[i].scatter(df['e'], df['scale_wh'+postfix], label='WH approximation', alpha=0.3)
    exponent = 1.0 if magnify else 0.5
    axs[i].plot(e_list_fine, 1/(1-e_list_fine**2)**exponent, '--', alpha=0.8, label=f'$\\frac{{r_{{50, 0}}}}{{(1-e^2)^{{{exponent}}}}}$')
    axs[i].plot(e_list_fine, f(e_list_fine), '--', alpha=0.8, label='interp1d linear')
    axs[i].plot(e_list_fine, f2(e_list_fine), '--', alpha=0.8, label='interp1d cubic')

    axs[i].legend()
    axs[i].set_xlabel('|e|')
    axs[i].set_ylabel(r'$r_{50, sheared}$')
    axs[i].set_title(f'$r_{50, 0}=1.0$ (magnify={magnify})')
    axs[i].set_yscale('log');

# %%
fig, axs = plt.subplots(2,2,figsize=(18,15))
plt.subplots_adjust(wspace=0.4, hspace=0.35)

for i, magnify in enumerate([True, False]):
    postfix = '_magnified' if magnify else ''
    f2 = interp1d(df['e'], df['scale_analytic'+postfix], kind='cubic', bounds_error=False, fill_value='extrapolate')
    axs[0,i].scatter(df['e'], (df['scale_analytic'+postfix]-df['scale_galsim'+postfix])/df['scale_analytic'+postfix],
                     marker='+', facecolors='orange', edgecolors='orange', s=100, alpha=0.7)
    axs[1,i].scatter(df['e'], (df['scale_analytic'+postfix]-f2(e_list))/df['scale_analytic'+postfix],
                     marker='+', facecolors='green', edgecolors='green', s=100, alpha=0.7)

    axs[0,i].axhline(y=0.0, color='r', linestyle='--')
    axs[1,i].axhline(y=0.0, color='r', linestyle='--')
    
    axs[0,i].set_xlabel('|e|')
    axs[1,i].set_xlabel('|e|')
    
    axs[0,i].set_title(f'magnify={magnify}')
    axs[1,i].set_title(f'magnify={magnify}')
    
    axs[0,i].set_ylabel('analytic-galsim / analytic');
    axs[1,i].set_ylabel('analytic-interp / analytic');

# %% [markdown]
# # Now test HLRShearModel

# %%
from shear_util import HLRShearModel

hsm = HLRShearModel('hlrshear.csv')
hsm.get_hlr_preshear([1.39,2.00,0.87],[0.18,0.75,0],magnify=False)
# Out:
# array([1.37384308, 1.2899341 , 0.87      ])

# %%
# test - we should get 1.995 back
hsm.get_hlr_preshear(hsm.get_hlr_postshear(1.995,0.66,False),0.66,False)
# Out:
# 1.995

# %%
hsm.get_hlr_postshear(hsm.get_hlr_preshear(1.995,0.66,False),0.66,False)
# Out:
# 1.995
